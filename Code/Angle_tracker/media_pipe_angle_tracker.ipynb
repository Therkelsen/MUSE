# %% [markdown]
# <h1>Install and import dependencies</h1>

# %%
# %pip install mediapipe opencv-python
# %pip uninstall opencv-python -y 

# %pip install opencv-python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (c:\Users\Simons Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Skipping opencv-python as it is not installed.
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.0)
# Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (c:\Users\Simons Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (c:\Users\Simons Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install notebook --upgrade
# Out:
# Collecting notebook
#   Downloading notebook-7.0.6-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook)
#   Downloading jupyter_server-2.9.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook)
#   Downloading jupyterlab_server-2.25.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<5,>=4.0.2 (from notebook)
#   Downloading jupyterlab-4.0.8-py3-none-any.whl.metadata (15 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook)
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from notebook) (6.3.3)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading anyio-4.0.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ---------------------------------------- 0.0/133.1 kB ? eta -:--:--
#      -------------------------------------- 133.1/133.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.4.0)
# Collecting jupyter-events>=0.6.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_events-0.9.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbconvert-7.11.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.2)
# Collecting overrides (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.2)
# Collecting prometheus-client (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading prometheus_client-0.18.0-py3-none-any.whl.metadata (26 kB)
# Collecting pywinpty (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading pywinpty-2.0.12-cp311-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.1)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.11.2)
# Collecting websocket-client (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading websocket_client-1.6.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4.0.2->notebook)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipykernel in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyterlab<5,>=4.0.2->notebook) (6.25.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4.0.2->notebook)
#   Downloading jupyter_lsp-2.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.22.1->notebook)
#   Downloading Babel-2.13.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.22.1->notebook)
#   Downloading json5-0.9.14-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.19.1)
# Requirement already satisfied: requests>=2.31 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (2.10)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (306)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Collecting rfc3339-validator (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      ---------------------------------------- 143.0/143.0 kB ? eta 0:00:00
# Collecting bleach!=5.0.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbclient-0.8.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.16.1)
# Collecting tinycss2 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: fastjsonschema in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2022.12.7)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (8.16.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.5.8)
# Requirement already satisfied: psutil in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.9.5)
# Requirement already satisfied: six>=1.9.0 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: backcall in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.0)
# Requirement already satisfied: decorator in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.19.1)
# Requirement already satisfied: pickleshare in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (3.0.39)
# Requirement already satisfied: stack-data in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.6.3)
# Requirement already satisfied: colorama in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.4.6)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pycparser in c:\users\simons lenovo\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.8)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\simons lenovo\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl.metadata (1.6 kB)
# Downloading notebook-7.0.6-py3-none-any.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 10.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 17.7 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/4.0 MB 17.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 3.6/4.0 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 15.0 MB/s eta 0:00:00
# Downloading jupyter_server-2.9.1-py3-none-any.whl (377 kB)
#    ---------------------------------------- 0.0/377.6 kB ? eta -:--:--
#    --------------------------------------- 377.6/377.6 kB 11.5 MB/s eta 0:00:00
# Downloading jupyterlab-4.0.8-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.2 MB 24.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.6/9.2 MB 20.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.4/9.2 MB 18.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.3/9.2 MB 19.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.0/9.2 MB 18.1 MB/s eta 0:00:01
#    -------------------- ------------------- 4.7/9.2 MB 17.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.2 MB 17.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.2/9.2 MB 17.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.2 MB 17.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.2 MB 17.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.2 MB 16.9 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.2 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 15.9 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.25.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.2 kB ? eta -:--:--
#    ---------------------------------------- 57.2/57.2 kB 3.1 MB/s eta 0:00:00
# Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.1 kB ? eta -:--:--
#    ---------------------------------------- 83.1/83.1 kB 4.9 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading Babel-2.13.1-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/10.1 MB 12.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.4/10.1 MB 15.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.2/10.1 MB 15.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.0/10.1 MB 15.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/10.1 MB 15.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.4/10.1 MB 15.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.4/10.1 MB 15.5 MB/s eta 0:00:01
#    ------------------- -------------------- 5.0/10.1 MB 13.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/10.1 MB 13.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/10.1 MB 13.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.0/10.1 MB 13.6 MB/s eta 0:00:01
#    ------------------------------ --------- 7.7/10.1 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.6/10.1 MB 14.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.1 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  10.1/10.1 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 14.0 MB/s eta 0:00:00
# Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Downloading jupyter_lsp-2.2.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/66.0 kB ? eta -:--:--
#    ---------------------------------------- 66.0/66.0 kB ? eta 0:00:00
# Downloading nbconvert-7.11.0-py3-none-any.whl (256 kB)
#    ---------------------------------------- 0.0/256.6 kB ? eta -:--:--
#    --------------------------------------- 256.6/256.6 kB 16.4 MB/s eta 0:00:00
# Downloading pywinpty-2.0.12-cp311-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------------- -------------- 0.9/1.4 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 14.9 MB/s eta 0:00:00
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.18.0-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#    ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Downloading websocket_client-1.6.4-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.3 kB ? eta -:--:--
#    ---------------------------------------- 57.3/57.3 kB 2.9 MB/s eta 0:00:00
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#    ---------------------------------------- 162.8/162.8 kB 9.5 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/48.0 kB ? eta -:--:--
#    ---------------------------------------- 48.0/48.0 kB ? eta 0:00:00
# Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.1 kB ? eta -:--:--
#    ---------------------------------------- 73.1/73.1 kB ? eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ---------------------------------------- 66.4/66.4 kB ? eta 0:00:00
# Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Installing collected packages: webencodings, types-python-dateutil, json5, websocket-client, webcolors, uri-template, tinycss2, soupsieve, sniffio, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-pygments, jsonpointer, jinja2, fqdn, defusedxml, bleach, babel, async-lru, terminado, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, jupyter-server-terminals, isoduration, argon2-cffi, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
# Successfully installed anyio-4.0.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.13.1 beautifulsoup4-4.12.2 bleach-6.1.0 defusedxml-0.7.1 fqdn-1.5.1 isoduration-20.11.0 jinja2-3.1.2 json5-0.9.14 jsonpointer-2.4 jupyter-events-0.9.0 jupyter-lsp-2.2.0 jupyter-server-2.9.1 jupyter-server-terminals-0.4.4 jupyterlab-4.0.8 jupyterlab-pygments-0.2.2 jupyterlab-server-2.25.0 mistune-3.0.2 nbclient-0.8.0 nbconvert-7.11.0 notebook-7.0.6 notebook-shim-0.2.3 overrides-7.4.0 pandocfilters-1.5.0 prometheus-client-0.18.0 python-json-logger-2.0.7 pywinpty-2.0.12 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.2 sniffio-1.3.0 soupsieve-2.5 terminado-0.17.1 tinycss2-1.2.1 types-python-dateutil-2.8.19.14 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (c:\Users\Simons Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (c:\Users\Simons Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import cv2
import csv
import time
import mediapipe
import numpy as np
import multiprocessing as mp
mp_drawing = mediapipe.solutions.drawing_utils
mp_pose = mediapipe.solutions.pose

print(cv2.__version__)
print(np.__version__)
# Out:
# 4.8.1
# 1.26.0

# %%
# Video feed
cap = cv2.VideoCapture(0) # number that represents the webcam == 0
while cap.isOpened():
    ret, frame = cap.read() # Gets the current feed from the camera. ret isn't used, frame gives the actual videoframe
    cv2.imshow('Mediapip Feed', frame)

    if cv2.waitKey(10) & 0xFF == ord('q'):  # Checks if we try to close the feed by pressing 'q'
        break

cap.release()   # Releases the webcam
cv2.destroyAllWindows()

# %% [markdown]
# <h1>Determining Joints</h1>

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px">

# %% [markdown]
# <h1>Calculate Angles</h1>

# %%
def calculate_angle(a, b, c):
    a = np.array(a) # First
    b = np.array(b) # Midd
    c = np.array(c) # End

    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)

    if angle > 180.0:
        angle = 360-angle
    
    return angle

# %%
# Video feed
cap = cv2.VideoCapture(0) # number that represents the webcam == 0

# Specify the file path where you want to save the CSV file
csv_file_path = 'elbow_angles.csv'

# Create an empty array to store angles
shape = (0, 1)
angles = np.zeros(shape)
times = np.zeros(shape)

# Initialize a variable to keep track of the start time
# start_time = time.time()

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        # current_time = time.time()

        # # Calculate the elapsed time in seconds
        # elapsed_time = current_time - start_time

        #     # Check if 1 second has passed
        # if elapsed_time >= 12.0:
        #     print("Broke loop after ", elapsed_time, " seconds")
        #     break  # Exit the loop after 1 second

        ret, frame = cap.read() # Gets the current feed from the camera. ret isn't used, frame gives the actual videoframe

        # Recolor image. frame comes in BGR, but we need it in RGB to predict the pose
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Make detection. Makes the predictions from the pose object to the image object, and stores it in results array
        results = pose.process(image)

        # Changes back to BGR, since openCV wants it in that format
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            # Get coordinates
            shoulder = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y
            elbow = landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y
            wrist = landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y

            # Calculate angle
            angle = calculate_angle(shoulder, elbow, wrist)

            # Save to angles array
            angles = np.vstack((angles, angle))
            # times = np.vstack((times, elapsed_time))

            # Visualize. Coordinates of the elbow is being multiplied by the webcam image resolution (640,480), to put the coordinate at the tip of the elbow
            cv2.putText(image, str(angle),
                        tuple(np.multiply(elbow, [640,480]).astype(int)),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                              )
                              
        except:
            pass

        # Render detections. Draws detections unto image. pose_landmarks gives all the predicted points and POSE_CONNECTIONS gives poit connections
        # draw_landmarks param: image as np array, list of landmarks, connections between landmarks, dots, lines
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow('Mediapip Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):  # Checks if we try to close the feed by pressing 'q'
            break

    cap.release()   # Releases the webcam
    cv2.destroyAllWindows()

    # Save to CSV
with open(csv_file_path, mode='w', newline='') as file:
    # Combine angle and time data into a list of lists
    # data = list(zip(angles, times))
    writer = csv.writer(file)
    writer.writerows(angles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Simons Lenovo\Documents\GitHub\MUSE\Code\Angle_tracker\media_pipe_angle_tracker.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a> times = np.zeros(shape)
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a> # Initialize a variable to keep track of the start time
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a> # start_time = time.time()
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> ## Setup mediapipe instance
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a> with mp_pose.Pose(running_mode='VIDEO', min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=16'>17</a>     while cap.isOpened():
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=17'>18</a>         # current_time = time.time()
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=18'>19</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a>         #     print("Broke loop after ", elapsed_time, " seconds")
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a>         #     break  # Exit the loop after 1 second
#      <a href='vscode-notebook-cell:/c%3A/Users/Simons%20Lenovo/Documents/GitHub/MUSE/Code/Angle_tracker/media_pipe_angle_tracker.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a>         ret, frame = cap.read() # Gets the current feed from the camera. ret isn't used, frame gives the actual videoframe
#
# TypeError: Pose.__init__() got an unexpected keyword argument 'running_mode'
